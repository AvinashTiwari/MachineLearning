# %% [markdown]
# <a href="https://colab.research.google.com/github/AvinashTiwari/MachineLearning/blob/master/Face_Detection_using_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2 
import numpy as np
from google.colab.patches import cv2_imshow
print(cv2.__version__)
print(np.__version__)
# Out:
# 4.6.0
# 1.22.4

# %%
image = cv2.imread("mask_1.jpg")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (360, 640, 3)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7FDFE89A54F0>
